# %% [markdown]
# Comparison (Relational) Operators - Compare two values and return a Boolean.

# %% [markdown]
# == (equal), != (not equal), >, <, >=, <=

# %%
a=5
b=6

# %%
a < b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %% [markdown]
# Logical operators - Combine conditional statements.

# %% [markdown]
# and, or, not

# %%
a = 5
b = 4

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a = 4

# %%
a == b
# Out:
# True

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 or b < 5
# Out:
# True

# %%
a > 8 or b < 2
# Out:
# False

# %%
x = False

# %%
not x
# Out:
# True

# %% [markdown]
# Bitwise operators - Perform bit-level operations on integers.

# %% [markdown]
# & (AND), | (OR), ^ (XOR), ~ (NOT), <<, >>

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(13)
# Out:
# '0b1101'

# %%
~12
# Out:
# -13

# %%
~15
# Out:
# -16

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12 ^ 13
# Out:
# 1

# %%
35 ^ 40
# Out:
# 11

# %% [markdown]
#  - Left Shift - we gain the bit <<
#  - Right Shift - we loose the bit >>

# %%
12 << 2
# Out:
# 48

# %%
12 << 1
# Out:
# 24

# %%
12 >> 1
# Out:
# 6

# %%
12 >> 2
# Out:
# 3

# %% [markdown]
# Swap 2 variables

# %%
a,b = 5,6
print(a)
print(b)
# Out:
# 5
# 6

# %%
temp = a
a = b
b = temp

# %%
print(a)
print(b)
# Out:
# 6
# 5

# %%
a = a+b
b = a-b
a = a-b
print(a)
print(b)
# Out:
# 5
# 6

# %%
a = a ^b
b = a ^b
a = a ^b
print(a)
print(b)
# Out:
# 6
# 5

# %%
a,b = b, a
print(a)
print(b)
# Out:
# 5
# 6
