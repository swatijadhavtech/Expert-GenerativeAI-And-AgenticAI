# %% [markdown]
# # Work With Numbers

# %%
5
# Out:
# 5

# %%
6
# Out:
# 6

# %%
-5
# Out:
# -5

# %%
5+6
# Out:
# 11

# %%
5+6-7*3-7
# Out:
# -17

# %% [markdown]
# BODMAS/PEMDAS Rule (Order of Operations)

# %%
5+6-7*(3-7)
# Out:
# 39

# %% [markdown]
# Some operating systems display an error for _ , although Google Colab works.

# %%
_ +3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 _ +3
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Work With String

# %%
nareshit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nareshit
#
# NameError: name 'nareshit' is not defined

# %% [markdown]
# String always write with ' ', " " or ''' ''' quotes

# %%
'nareshit'
# Out:
# 'nareshit'

# %%
"nareshit"
# Out:
# 'nareshit'

# %%
'''nareshit'''
# Out:
# 'nareshit'

# %%
'nareshit
     technology'
# Out:
#   Cell In[7], line 1
#     'nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"nareshit
     technology"
# Out:
#   Cell In[8], line 1
#     "nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Note: in the result, the line breaks are inserted at the same position as in the code.

# %%
'''nareshit
     technology'''
# Out:
# 'nareshit\n     technology'
