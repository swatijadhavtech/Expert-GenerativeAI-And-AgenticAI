# %%
'Welcome to Naresh IT'
# Out:
# 'Welcome to Naresh IT'

# %% [markdown]
# Arithmetic Operators

# %%
2+3
# Out:
# 5

# %%
2-3
# Out:
# -1

# %%
3*3
# Out:
# 9

# %% [markdown]
# Division (returns a float)

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# Exponentiation

# %%
3**3
# Out:
# 27

# %% [markdown]
# Floor division (returns an integer, rounds DOWN to the nearest integer )

# %%
10//2
# Out:
# 5

# %% [markdown]
# Modulus (returns the remainder)

# %%
10%2
# Out:
# 0
