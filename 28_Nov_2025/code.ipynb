# %% [markdown]
# # Variables

# %% [markdown]
# Variables are containers for storing data values.

# %%
v=5
v
# Out:
# 5

# %% [markdown]
# Get address of the variable

# %%
id(v)
# Out:
# 140719245800488

# %% [markdown]
# # Rules for Python Variables

# %% [markdown]
# Variable names are case-sensitive

# %%
nit = 8
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 nit = 8
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 8

# %% [markdown]
# A variable name cannot start with a number

# %%
8nit=nit
# Out:
#   Cell In[7], line 1
#     8nit=nit
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# A variable name can only contain alpha-numeric characters and underscores

# %%
nit$ = 78
# Out:
#   Cell In[6], line 1
#     nit$ = 78
#        ^
# SyntaxError: invalid syntax

# %%
nit_=78
nit_
# Out:
# 78

# %% [markdown]
# A variable name cannot be any of the Python keywords.

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
def = 45
def
# Out:
#   Cell In[11], line 1
#     def = 45
#         ^
# SyntaxError: invalid syntax

# %%
If= 90
If
# Out:
# 90

# %%
4-3
# Out:
# 1

# %% [markdown]
# print() function is required to print only one line output

# %%
print(3+4)
# Out:
# 7
