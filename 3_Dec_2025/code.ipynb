# %% [markdown]
# # Data Structures

# %% [markdown]
# Data structures are a way of storing and organizing data efficiently.

# %% [markdown]
# The primary built-in data structures are lists, tuples, sets, and dictionaries.

# %% [markdown]
# # list

# %% [markdown]
# An ordered collection of items that is mutable (changeable) and allows duplicate members. They are created using square brackets []

# %%
l =[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %% [markdown]
# append() - This method in Python is used to add a single item to the end of list

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)

# %%
l
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# copy() - it is used to create a shallow copy of list

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l1.append('hi', 1+2j,2.3,True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 l1.append('hi', 1+2j,2.3,True)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %%
l1.append(2.4)
l1.append(1+2j)
l1.append(True)
l1.append('hi')
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'hi', 2.4, (1+2j), True, 'hi']

# %%
print(len(l1))
# Out:
# 12

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 10]

# %% [markdown]
# insert() – Adds an element to a specific position in the list that needs to be specified along with the value

# %%
l3 = [1,2,3,4,5,6,7,8,'prakash','senapati,',1+2j,True]
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 'prakash', 'senapati,', (1+2j), True]

# %%
l3.insert(2,'hi')
l3
# Out:
# [1, 2, 'hi', 3, 4, 5, 6, 7, 8, 'prakash', 'senapati,', (1+2j), True]

# %%
l3.clear()
l3
# Out:
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l.count(20)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l[:]
# Out:
# [10, 20, 30, 40, 10]

# %%
l[2:]
# Out:
# [30, 40, 10]

# %%
l[:-1]
# Out:
# [10, 20, 30, 40]

# %%
l[::-1]  # reverse the list
# Out:
# [10, 40, 30, 20, 10]

# %%
l[:::-1]
# Out:
#   Cell In[35], line 1
#     l[:::-1]
#         ^
# SyntaxError: invalid syntax

# %%
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'hi', 2.4, (1+2j), True, 'hi']

# %% [markdown]
# index() - This method returns the zero-based index of the first occurrence of a specified value in a list.

# %%
l1.index('hi')
# Out:
# 7

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
l[:2]
# Out:
# [10, 20]

# %%
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'hi', 2.4, (1+2j), True, 'hi']

# %%
l1[1:10:3]
# Out:
# [20, 2.4, 'hi']

# %%
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'hi', 2.4, (1+2j), True, 'hi']

# %%
l1[3:5:6]
# Out:
# [40]

# %%
l1[1:10:3]
# Out:
# [20, 2.4, 'hi']

# %%
l = [10, 20, 30, 40]
l
# Out:
# [10, 20, 30, 40]

# %%
l[0]
# Out:
# 10

# %% [markdown]
# List is mutable

# %%
l[0] = 100
l
# Out:
# [100, 20, 30, 40]

# %%
l[-1] = 1000
l
# Out:
# [100, 20, 30, 1000]

# %%
l1 =[10, 20, 30, 40, 2.4, (1+2j), True, 'hi']

# %%
l2 = []
l2
# Out:
# []

# %% [markdown]
# extend() - This method adds the specified list elements (or any iterable) to the end of the current list.

# %%
l2.extend(l1)
l2
# Out:
# [10,
#  20,
#  30,
#  40,
#  2.4,
#  (1+2j),
#  True,
#  'hi',
#  10,
#  20,
#  30,
#  40,
#  2.4,
#  (1+2j),
#  True,
#  'hi']

# %%
l2.extend(l)
l2
# Out:
# [10,
#  20,
#  30,
#  40,
#  2.4,
#  (1+2j),
#  True,
#  'hi',
#  10,
#  20,
#  30,
#  40,
#  2.4,
#  (1+2j),
#  True,
#  'hi',
#  10,
#  20,
#  30,
#  40,
#  10,
#  20,
#  30,
#  40]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40, 2.4, (1+2j), True, 'hi']
# [10, 20, 30, 40, 2.4, (1+2j), True, 'hi', 10, 20, 30, 40, 2.4, (1+2j), True, 'hi', 10, 20, 30, 40, 10, 20, 30, 40]

# %%
l.extend(l1,l2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l.extend(l1,l2)
#
# TypeError: list.extend() takes exactly one argument (2 given)

# %%
l.index(20)
# Out:
# 1

# %%
l.index(2000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 l.index(2000)
#
# ValueError: 2000 is not in list

# %%
for i in l1:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 2.4
# (1+2j)
# True
# hi

# %% [markdown]
# enumerate() - It is used to loop over an iterable and get both the index and the element at the same time.

# %%
for i in enumerate(l1):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, 40)
# (4, 2.4)
# (5, (1+2j))
# (6, True)
# (7, 'hi')

# %%
l
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# pop() - This method remove and return item at index (default last).

# %%
l.pop()
l
# Out:
# [10, 20, 30]

# %%
l.pop(0)
# Out:
# 10

# %%
l.pop(8)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l.pop(8)
#
# IndexError: pop index out of range

# %%
l1
# Out:
# [10, 20, 30, 40, 2.4, (1+2j), True, 'hi']

# %% [markdown]
# remove() - This method remove value based on value not based on index

# %%
l1.remove(40)

# %% [markdown]
# reverse() - This method reverses the order of elements in a list.

# %%
l1.reverse()
l1
# Out:
# ['hi', True, (1+2j), 2.4, 30, 20, 10]

# %%
l1[::-1]
# Out:
# [10, 20, 30, 2.4, (1+2j), True, 'hi']

# %% [markdown]
# Sorting is possible only when user declare similar datatype

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'bool' and 'str'

# %%
l.sort()
l
# Out:
# [20, 30]

# %%
l3 = ['z','x','m']
l3.sort()
l3
# Out:
# ['m', 'x', 'z']

# %%
l3.sort(reverse=True)
l3
# Out:
# ['z', 'x', 'm']

# %% [markdown]
# 'in' statement - checks if an element is present in an iterable or not.

# %%
'z' in l3
# Out:
# True

# %%
'b' in l3
# Out:
# False

# %% [markdown]
# all(iterable) - The all() function returns True if all elements in the iterable are truthy (evaluate to True in a boolean context), or if the iterable is empty. Otherwise, it returns False

# %%
all(l)
# Out:
# True

# %% [markdown]
# any(iterable) - The any() function returns True if any element in the iterable is truthy. If the iterable is empty or all elements are falsy, it returns False

# %%
any(l)
# Out:
# True

# %%
l.append(0)
l
# Out:
# [10, 20, 30, 40, 0]

# %%
all(l)
# Out:
# False

# %%
any(l)
# Out:
# True
